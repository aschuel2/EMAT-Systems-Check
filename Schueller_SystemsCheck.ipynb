# %% [markdown]
# # Systems Check

# %% [markdown]
# ## EMAT 22110 - Data in Emerging Media and Technology

# %% [markdown]
# ### Author: Alyssa Schueller

# %% [markdown]
# I am excited to take this class with Dr. Silva. What I hope to get out of this course is:

# %% [markdown]
# * a better understanding of data analysis
# * a broader view at Python
# * learning report writing, sharing and documentation using LaTeX and RMarkdown
# * learn how to make data-based decisions

# %% [markdown]
# ![IMG_2624-3.jpg](attachment:IMG_2624-3.jpg)

# %% [markdown]
# I didn't know what image to use so this is a picture I took for my photography class I took last year.

# %% [markdown]
# ### Variable Assignment

# %%
one = 1

# %% [markdown]
# ### Basic Loop

# %%
classes = ["math", "science", "english"]

# %% [markdown]
# ### Print Statement

# %%
for x in classes:
    print(x)
# Out:
# math
# science
# english

# %% [markdown]
# ### Return Statement

# %%
def add(a, b):
    return a + b
def is_true(a):
    return bool(a)
res = add(2,3)
print("Result of add function is{}".format(res) )
# Out:
# Result of add function is5
